# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('/content/0003c4a244a92d80c5acf749361692e9.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1304, 2000, 3)

# %%
plt.imshow(img)

# %%
img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_rgb)

# %%
img_gray = cv2.imread('/content/0003c4a244a92d80c5acf749361692e9.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1304, 2000)

# %%
img_gray2 = cv2.imread('/content/0003c4a244a92d80c5acf749361692e9.jpg',0)

# %%
img_gray.min()
# Out:
# np.uint8(0)

# %%
plt.imshow(img_gray2)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
img_res = cv2.resize(img_gray,None, fx=0.5, fy=0.5) #reoderna por MEIO o tamanho da imagem bom para imagens muito grandes

# %%
plt.imshow(img_res)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
nova_img = cv2.resize(img_rgb,(0,0),img_rgb,w_ratio,h_ratio)

# %%
plt.imshow(nova_img)

# %%
imagem_flp = cv2.flip(img_rgb,1)
plt.imshow(imagem_flp)
# 0 - Vertical
# 1 - Horizontal
# -1 - Ambos

# %%
cv2.imwrite('teste.jpg',img_gray)
# Out:
# True

# %%
#Aumentar Saída do PyPlot
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(img_rgb)
