# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img1 = cv2.imread('doc.png')
img2 = cv2.imread('secret.png')

# %%
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
img_menor = cv2.resize(img2,(200,200))

# %%
img_menor.shape
# Out:
# (200, 200, 3)

# %%
plt.imshow(img_menor)

# %%
img1.shape
# Out:
# (400, 400, 3)

# %%
plt.imshow(img1)

# %%
img_maior = img1

# %%
x_offset = 100
y_offset = 100

# %%
img_menor.shape
# Out:
# (200, 200, 3)

# %%
x_end = x_offset + img_menor.shape[0]
y_end = y_offset + img_menor.shape[1]

# %%
img_maior[y_offset:y_end,x_offset:x_end] = img_menor

# %%
plt.imshow(img_maior)
