# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 kB 23.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 98.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
#dectcao de imagem -> usando o modelo nano
from ultralytics import YOLO

model = YOLO("yolo11n.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 93.1MB/s]

# %%
resultado = model("/content/dog.jpeg")

#usar um modelo mais robusto para esses exemplos ->

resultado2 = model("/content/Exp-6.-Explorar-a-maior-floresta-urbana-do-mundo-scaled.jpg")

resultado3 = model("/content/istockphoto-157482648-612x612.jpg")
# Out:
# image 1/1 /content/dog.jpeg: 480x640 1 bicycle, 1 car, 1 truck, 1 dog, 26.6ms
# Speed: 6.7ms preprocess, 26.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/Exp-6.-Explorar-a-maior-floresta-urbana-do-mundo-scaled.jpg: 448x640 (no detections), 20.3ms
# Speed: 4.1ms preprocess, 20.3ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/istockphoto-157482648-612x612.jpg: 448x640 (no detections), 11.9ms
# Speed: 3.5ms preprocess, 11.9ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)

# %%
#salvando as caixas para a interpretacao das imagens

for resultado in resultado:
  photo = resultado.boxes
  resultado.save(filename='foto1.jpg')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as npimg

imagem = '/content/foto1.jpg'
img = npimg.imread(imagem)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# !pip install matplotlib opencv-python

# %% [markdown]
# A parte de analisar os dados da imagem que foi usado o algoritimo do YOLO para o reconhecimento de imagem
